# %%
import mediapy as media
from pathlib import Path

# %%
# img = mediapy.read_image("/home/cw4287/gaussian-model/train_30k/test/ours_30000/renders")

# mediapy.show_image(img)

# 图片所在的文件夹
folder = Path("/home/cw4287/gaussian-model/train_WD_erank_30k/test/ours_30000/renders")

# 找到所有 png 文件并排序（按文件名）
img_paths = sorted(folder.glob("*.png"))

# 逐张读入并展示
for p in img_paths:
    img = media.read_image(str(p))
    media.show_image(img, title=p.name)  # title 可选
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       1 # img = mediapy.read_image("/home/cw4287/gaussian-model/train_30k/test/ours_30000/renders")
#       2
#       3 # mediapy.show_image(img)
#    (...)      7
#       8 # 找到所有 png 文件并排序（按文件名）
# ----> 9 img_paths = sorted(folder.glob("*.png"))
#      11 # 逐张读入并展示
#      12 for p in img_paths:
#
# NameError: name 'folder' is not defined

# %%
# img = mediapy.read_image("/home/cw4287/gaussian-model/train_30k/test/ours_30000/renders")

# mediapy.show_image(img)

# 图片所在的文件夹
# folder = Path("/home/cw4287/gaussian-model/train_30k/test/ours_30000/renders")

# 找到所有 png 文件并排序（按文件名）
img_paths = sorted(folder.glob("*.png"))

# 逐张读入并展示
for p in img_paths:
    img = media.read_image(str(p))
    media.show_image(img, title=p.name)  # title 可选
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       1 # img = mediapy.read_image("/home/cw4287/gaussian-model/train_30k/test/ours_30000/renders")
#       2
#       3 # mediapy.show_image(img)
#    (...)      7
#       8 # 找到所有 png 文件并排序（按文件名）
# ----> 9 img_paths = sorted(folder.glob("*.png"))
#      11 # 逐张读入并展示
#      12 for p in img_paths:
#
# NameError: name 'folder' is not defined

# %%
folder = Path("/vast/cw4287/gaussian-model/db/playroom_train_WD_scales_3_log2sigma2_thin1/stats/eranks/")

# 找到所有 png 文件并排序（按文件名）
img_paths = sorted(folder.glob("*.png"))

# 逐张读入并展示
for p in img_paths:
    img = media.read_image(str(p))
    media.show_image(img, title=p.name)  # title 可选
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>30000.png</div><div><img width="800" height="600" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></div></div></div></td></tr></table>

# %%
folder = Path("/vast/cw4287/gaussian-model/tandt/train_train_model/stats/eranks/")

# 找到所有 png 文件并排序（按文件名）
img_paths = sorted(folder.glob("*.png"))

# 逐张读入并展示
for p in img_paths:
    img = media.read_image(str(p))
    media.show_image(img, title=p.name)  # title 可选
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>30000.png</div><div><img width="800" height="600" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></div></div></div></td></tr></table>
